# %%
# a script that evaluates each line in a list of potential crossword puzzle entries
# to locate entries whose first halves match their second halves

# crossword entry lists are generally text files in which each line contains
# the entry, followed by a semicolon, then a score the construction program algorithm uses to
# sort potential entries, e.g. "entry;50"
# this function strips the word scores from the entries
# and returns entries of the desired length

def shorten(f, entry_length):
  shortened_output = []
  with open(f) as list:
    for l in list:
      x = l[0:l.find(";")]
      if len(x) == int(entry_length):
        shortened_output.append(x)
  return(shortened_output)

def main():

  # insert link to word list here
  wdlist = "#"

  # list to which potential entries will be appended
  out = []

  # crossword entries are always at least 3 characters
  # and almost never longer than 21 characters
  for x in range(4, 24, 2):
    ents = shorten(wdlist, x)

    for i in range(len(ents)):
      y = ents[i]
      if y not in out:
        if y[0:int(len(y) / 2)] == y[int(len(y) / 2):]:
          out.append(y)

  for z in range(len(out)):
    print(out[z])

main()
# Out:
# baba
# bebe
# cece
# coco
# dada
# dodo
# gaga
# gigi
# gogo
# haha
# hehe
# hoho
# idid
# isis
# keke
# kiki
# lala
# lili
# lulu
# mama
# meme
# mimi
# momo
# mymy
# nana
# nene
# nono
# ohoh
# okok
# papa
# pepe
# pupu
# riri
# sisi
# soso
# tata
# tete
# toto
# tutu
# uhuh
# wawa
# xoxo
# yoyo
# arfarf
# ayeaye
# baabaa
# berber
# bonbon
# booboo
# byebye
# cancan
# chacha
# chichi
# dandan
# deedee
# dikdik
# dumdum
# etcetc
# heehee
# idoido
# kenken
# laalaa
# leelee
# maumau
# murmur
# muumuu
# naenae
# oleole
# oneone
# oohooh
# ouioui
# pawpaw
# pompom
# rahrah
# sensen
# tamtam
# tartar
# taytay
# tintin
# tomtom
# tsetse
# tsktsk
# tuttut
# usausa
# wahwah
# winwin
# yesyes
# yumyum
# agaragar
# amenamen
# antianti
# bammbamm
# bangbang
# beepbeep
# beriberi
# blahblah
# boomboom
# borabora
# choochoo
# chopchop
# chowchow
# chumchum
# ciaociao
# couscous
# fizzfizz
# froufrou
# halohalo
# healheal
# hearhear
# hinthint
# hotshots
# hulahula
# hushhush
# johnjohn
# kavakava
# latelate
# liarliar
# likelike
# lisalisa
# loselose
# mahimahi
# nananana
# nanunanu
# noelnoel
# nononono
# okayokay
# oyezoyez
# pagopago
# periperi
# piripiri
# poohpooh
# puttputt
# singsing
# suresure
# togatoga
# toottoot
# wellwell
# whoawhoa
# wikiwiki
# winkwink
# xoxoxoxo
# xxxxxxxx
# yadayada
# yeahyeah
# zerozero
# zoomzoom
# andonandon
# badenbaden
# blingbling
# boolaboola
# buddybuddy
# duranduran
# extraextra
# fiftyfifty
# goodygoody
# honeyhoney
# hubbahubba
# iknowiknow
# knockknock
# louielouie
# mariamaria
# namesnames
# nightnight
# peterpeter
# radioradio
# romeoromeo
# shabushabu
# sugarsugar
# therethere
# tiboktibok
# tygertyger
# vroomvroom
# wallawalla
# waterwater
# cherrycherry
# circuscircus
# doubledouble
# hearyehearye
# mirrormirror
# mondaymonday
# peoplepeople
# sirhansirhan
# timingtiming
# absalomabsalom
# excusesexcuses
# gorillagorilla
# humberthumbert
# newyorknewyork
